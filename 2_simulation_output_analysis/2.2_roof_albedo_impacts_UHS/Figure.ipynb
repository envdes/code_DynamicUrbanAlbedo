# %% [markdown]
# # UHS and TBUILD figure
# - This script is used to visualize UHS indice and TBUILD;
# - Simulations: CNTL, ROOF_0.9, ROOF_DA

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import MultipleLocator
import textwrap

# %%
home_path = '/work/n02/n02/yuansun/'
path = home_path + 'output_analysis/project1/UHS/'
file_path0 = path + 'exported_data_UHS0.csv'
df0 = pd.read_csv(file_path0)
for column_name in df0.columns:
    globals()[column_name] = df0[column_name]   

file_path1 = path + 'exported_data_UHS1.csv'
df1 = pd.read_csv(file_path1)
for column_name in df1.columns:
    globals()[column_name] = df1[column_name]  

file_path2 = path + 'exported_data_UHS2.csv'
df2 = pd.read_csv(file_path2)
for column_name in df2.columns:
    globals()[column_name] = df2[column_name]

# %%
# drawing
start_year = 2015
end_year = 2099
linewidth = 0.5
linewidth2 = 1
fontsize = 6
labelfont = 6
labelcolor = '#6b6b6b'
lc1 = '#6e1913'
lc2 = '#a42018'
lc3 = '#f62d18'
lc4 = '#d97c26'
lc5 = '#ff912b'
lc6 = '#30b5d6'
lc7 = '#28ac92'
lc8 = '#1235b6'
lc9 = '#05101f'
lc10 = '#952cc6'
minor_locator = MultipleLocator(10)
specific_years = [2015, 2050, 2099]
alpha=0.075
handletextpad = 0.5
pad = 1
padt = 0.5
length = 4
distance = 5
padding = 4
data = [[[Arr_HIA_U_0, Arr_HIA_U_1,Arr_HIA_U_2], [Arr_HIA_U_0_JJA, Arr_HIA_U_1_JJA, Arr_HIA_U_2_JJA], [Arr_HIA_U_0_DJF, Arr_HIA_U_1_DJF,Arr_HIA_U_2_DJF]],
        [[Arr_APPAR_TEMP_U_0, Arr_APPAR_TEMP_U_1,Arr_APPAR_TEMP_U_2], [Arr_APPAR_TEMP_U_0_JJA, Arr_APPAR_TEMP_U_1_JJA, Arr_APPAR_TEMP_U_2_JJA], [Arr_APPAR_TEMP_U_0_DJF, Arr_APPAR_TEMP_U_1_DJF,Arr_APPAR_TEMP_U_2_DJF]],
        [[Arr_SWBGT_U_0, Arr_SWBGT_U_1,Arr_SWBGT_U_2], [Arr_SWBGT_U_0_JJA, Arr_SWBGT_U_1_JJA, Arr_SWBGT_U_2_JJA], [Arr_SWBGT_U_0_DJF, Arr_SWBGT_U_1_DJF,Arr_SWBGT_U_2_DJF]],
        [[Arr_HUMIDEX_U_0, Arr_HUMIDEX_U_1,Arr_HUMIDEX_U_2], [Arr_HUMIDEX_U_0_JJA, Arr_HUMIDEX_U_1_JJA, Arr_HUMIDEX_U_2_JJA], [Arr_HUMIDEX_U_0_DJF, Arr_HUMIDEX_U_1_DJF,Arr_HUMIDEX_U_2_DJF]],
        [[Arr_DISCOIS_U_0, Arr_DISCOIS_U_1,Arr_DISCOIS_U_2], [Arr_DISCOIS_U_0_JJA, Arr_DISCOIS_U_1_JJA, Arr_DISCOIS_U_2_JJA], [Arr_DISCOIS_U_0_DJF, Arr_DISCOIS_U_1_DJF,Arr_DISCOIS_U_2_DJF]],
        [[Arr_TBUILD_0_C, Arr_TBUILD_1_C,Arr_TBUILD_2_C], [Arr_TBUILD_0_JJA_C, Arr_TBUILD_1_JJA_C, Arr_TBUILD_2_JJA_C], [Arr_TBUILD_0_DJF_C, Arr_TBUILD_1_DJF_C,Arr_TBUILD_2_DJF_C]]
       ]
label = [['CNTL - ANN', 'ROOF_0.9 - ANN', 'ROOF_DA - ANN'], 
         ['CNTL - JJA', 'ROOF_0.9 - JJA', 'ROOF_DA - JJA'], 
         ['CNTL - DJF', 'ROOF_0.9 - DJF', 'ROOF_DA - DJF']]
lc = [lc1, lc3, lc7]
linestyle = ['-', ':', '--']
title = ['(a) NWS_HI', '(b) AT', '(c) sWBGT', '(d) HUMIDEX', '(e) DI', '(f) TBUILD']
la = ['℃', '℃', '℃','℃','℃','℃']
yi = 10
ym = 36
ymin = [yi, yi, yi, yi, 10, 17]
ymax = [ym, ym, ym, ym, 27, 31]
xwidth = 0.75
sizes = 2
year_offset = 20

# %%
fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(5.5, 2.75))
ax = axes.flatten()
for i in range(6):
    for j in range(3):
        for m in range(3):
            ax[i].plot(time, data[i][j][m], linewidth=linewidth, linestyle = linestyle[j], label = label[j][m], color = lc[m])
    ax[i].set_title(title[i],fontsize=fontsize,color=labelcolor, pad = padding)   
    ax[i].set_xlim(start_year,end_year)
    ax[i].yaxis.offsetText.set_fontsize(labelfont)
    ax[i].tick_params(axis='y', which='both', left=False, right=False, labelleft=True, labelcolor=labelcolor, labelsize=labelfont, pad=pad, color = labelcolor, width = xwidth)
    ax[i].tick_params(axis='x', which='major', top=False, bottom=True, labelbottom=True, labelcolor=labelcolor, labelsize=labelfont, pad=pad, color = labelcolor, width = xwidth, length = length)
    ax[i].tick_params(axis='x', which='minor', top=False, bottom=True, labelbottom=True, labelcolor=labelcolor, labelsize=labelfont, pad=pad, color = labelcolor, width = xwidth, length = length/2)
    ax[i].spines['left'].set_visible(False)
    ax[i].spines['top'].set_visible(False)
    ax[i].spines['right'].set_visible(False)
    ax[i].spines['bottom'].set_color(labelcolor)
    ax[i].xaxis.set_minor_locator(minor_locator)
    ax[i].set_xticks(specific_years)
    ax[i].grid(True, which='major', axis='y',linestyle='--',linewidth=0.5, alpha=0.5)
    ax[i].set_ylim(ymin[i], ymax[i])
    ax[i].fill_betweenx([ymin[i], ymax[i]],2021, 2040, color=lc9, alpha=alpha, label='Near-term',edgecolor='none')
    ax[i].fill_betweenx([ymin[i], ymax[i]],2041, 2060, color=lc5, alpha=alpha, label='Mid-term',edgecolor='none')
    ax[i].fill_betweenx([ymin[i], ymax[i]],2081, 2100, color=lc2, alpha=alpha, label='Long-term',edgecolor='none')
    ax[i].set_ylabel(la[i], labelpad=5, rotation=0, ha='center', fontsize=labelfont,color=labelcolor)
    ax[i].yaxis.set_label_coords(0, 1.05)

axes[0,0].hlines(y=27, xmin=min(time), xmax=max(time), linewidth=linewidth, color=labelcolor, linestyle='--')
axes[0,0].text(max(time), 27, '27℃', verticalalignment='center', fontsize=labelfont, color=labelcolor)
axes[0,0].scatter(2037, 27, color=lc1, s=sizes)
axes[0,0].scatter(2050, 27, color=lc3, s=sizes)
axes[0,0].scatter(2041, 27, color=lc7, s=sizes)

axes[0,0].hlines(y=33, xmin=min(time), xmax=max(time), linewidth=linewidth, color=labelcolor, linestyle='--')
wrapped_text = textwrap.fill('33℃', width=8)
axes[0,0].text(max(time), 33, wrapped_text, verticalalignment='center', fontsize=labelfont, color=labelcolor)
axes[0,0].text(2015, 34, '•2037', fontsize=labelfont, color=lc1)
axes[0,0].text(2015 + year_offset, 34, '•2050', fontsize=labelfont, color=lc3)
axes[0,0].text(2015 + year_offset*2, 34, '•2041', fontsize=labelfont, color=lc7)

axes[0,2].hlines(y=26.7, xmin=min(time), xmax=max(time), linewidth=linewidth, color=labelcolor, linestyle='--')
axes[0,2].text(max(time), 26.7, '26.7℃', verticalalignment='center', fontsize=labelfont, color=labelcolor)
axes[0,2].hlines(y=29.4, xmin=min(time), xmax=max(time), linewidth=linewidth, color=labelcolor, linestyle='--')
axes[0,2].text(max(time), 29.4, '29.4℃', verticalalignment='center', fontsize=labelfont, color=labelcolor)
axes[0,2].scatter(2059, 26.7, color=lc1, s=sizes)
axes[0,2].scatter(2063, 26.7, color=lc3, s=sizes)
axes[0,2].scatter(2060, 26.7, color=lc7, s=sizes)
axes[0,2].text(2015, 34, '•2059', fontsize=labelfont, color=lc1)
axes[0,2].text(2015 + year_offset, 34, '•2063', fontsize=labelfont, color=lc3)
axes[0,2].text(2015 + year_offset*2, 34, '•2060', fontsize=labelfont, color=lc7)

axes[1,0].hlines(y=30, xmin=min(time), xmax=max(time), linewidth=linewidth, color=labelcolor, linestyle='--')
wrapped_text2 = textwrap.fill('30℃', width=12)  
axes[1,0].text(max(time), 30, wrapped_text2, verticalalignment='center', fontsize=labelfont, color=labelcolor)
axes[1,0].scatter(2030, 30, color=lc1, s=sizes)
axes[1,0].scatter(2040, 30, color=lc3, s=sizes)
axes[1,0].scatter(2030, 30, color=lc7, s=sizes)
axes[1,0].text(2015, 34, '•2030', fontsize=labelfont, color=lc1)
axes[1,0].text(2015 + year_offset, 34, '•2040', fontsize=labelfont, color=lc3)
axes[1,0].text(2015 + year_offset*2, 34, '•2030', fontsize=labelfont, color=lc7)

axes[1,1].hlines(y=21, xmin=min(time), xmax=max(time), linewidth=linewidth, color=labelcolor, linestyle='--')
wrapped_text3 = textwrap.fill('<50%', width=12)  
axes[1,1].text(max(time), 21, wrapped_text3, verticalalignment='center', fontsize=labelfont, color=labelcolor)

axes[1,1].hlines(y=24, xmin=min(time), xmax=max(time), linewidth=linewidth, color=labelcolor, linestyle='--')
wrapped_text4 = textwrap.fill('>50%', width=12) 
axes[1,1].text(max(time), 24, wrapped_text4, verticalalignment='center', fontsize=labelfont, color=labelcolor)
axes[1,1].scatter(2080, 24, color=lc1, s=sizes)
axes[1,1].scatter(2084, 24, color=lc3, s=sizes)
axes[1,1].scatter(2084, 24, color=lc7, s=sizes)
axes[1,1].text(2015, 25.7, '•2080', fontsize=labelfont, color=lc1)
axes[1,1].text(2015 + year_offset, 25.7, '•2084', fontsize=labelfont, color=lc3)
axes[1,1].text(2015 + year_offset*2, 25.7, '•2084', fontsize=labelfont, color=lc7)

axes[1,2].hlines(y=28, xmin=min(time), xmax=max(time), linewidth=linewidth, color=labelcolor, linestyle='--')
wrapped_text2 = textwrap.fill('28℃', width=12)  
axes[1,2].text(max(time), 28, wrapped_text2, verticalalignment='center', fontsize=labelfont, color=labelcolor)
axes[1,2].scatter(2059, 28, color=lc1, s=sizes)
axes[1,2].scatter(2094, 28, color=lc3, s=sizes)
axes[1,2].scatter(2094, 28, color=lc7, s=sizes)
axes[1,2].hlines(y=19, xmin=min(time), xmax=max(time), linewidth=linewidth, color=labelcolor, linestyle='--')
wrapped_text2 = textwrap.fill('19℃', width=12) 
axes[1,2].text(max(time), 19, wrapped_text2, verticalalignment='center', fontsize=labelfont, color=labelcolor)    
#axes[1,2].scatter(2015, 19, color=lc1, s=sizes)
axes[1,2].scatter(2078, 19, color=lc3, s=sizes)
#axes[1,2].scatter(2015, 19, color=lc7, s=sizes) 
axes[1,2].text(2015, 30, '•2059', fontsize=labelfont, color=lc1)
axes[1,2].text(2015 + year_offset, 30, '•2094', fontsize=labelfont, color=lc3)
axes[1,2].text(2015 + year_offset*2, 30, '•2094', fontsize=labelfont, color=lc7)
axes[1,2].text(2078, 17.5, '2078', fontsize=labelfont, color=lc3)

lines, labels = axes[0,0].get_legend_handles_labels()

plt.subplots_adjust(left=0.035, right=0.945, bottom=0.225, top=0.94, wspace=0.35, hspace=0.5)
legend = fig.legend(lines, labels, bbox_to_anchor=(0.5, -0.01), loc='lower center', frameon=False, handletextpad=handletextpad, fontsize=labelfont, ncol=4)
lc = [lc1, lc3, lc7, lc1, lc3, lc7, lc1, lc3, lc7, lc9, lc5, lc2]
for i, text in enumerate(legend.get_texts()):
    text.set_color(lc[i])
        
plt.show()
fig.savefig(path + 'UHS.png', dpi=300)

# %%
fig.savefig(path + 'UHS.pdf', dpi=600)

# %% [markdown]
# ## Description

# %%
print((Arr_HIA_U_1-Arr_HIA_U_0).mean(), (Arr_HIA_U_1-Arr_HIA_U_0).std())
# Out:
# -0.5545496323529412 0.0072837863906009695

# %%
print(Arr_HIA_U_1[0], Arr_HIA_U_1[0]-Arr_HIA_U_0[0])

# %%
print((Arr_APPAR_TEMP_U_1-Arr_APPAR_TEMP_U_0).mean(), (Arr_APPAR_TEMP_U_1-Arr_APPAR_TEMP_U_0).std())
# Out:
# -0.3730286542107074 0.0034778090002105964

# %%
print((Arr_SWBGT_U_1-Arr_SWBGT_U_0).mean(), (Arr_SWBGT_U_1-Arr_SWBGT_U_0).std())
# Out:
# -0.25747487685259673 0.0022723104535587184

# %%
print((Arr_HUMIDEX_U_1-Arr_HUMIDEX_U_0).mean(), (Arr_HUMIDEX_U_1-Arr_HUMIDEX_U_0).std())
# Out:
# -0.466034474092372 0.003787115858106815

# %%
print((Arr_DISCOIS_U_1-Arr_DISCOIS_U_0).mean(), (Arr_DISCOIS_U_1-Arr_DISCOIS_U_0).std())
# Out:
# -0.334195125804228 0.0033349806195185298

# %%
print(Arr_TBUILD_0_JJA_C[84], Arr_TBUILD_0_JJA_C[84]-Arr_TBUILD_0_JJA_C[0])
# Out:
# 30.119042968750023 3.732879638671875

# %%
print(Arr_TBUILD_0_DJF_C[84]-Arr_TBUILD_0_DJF_C[0])

# %%
print(Arr_TBUILD_1_C[84],Arr_TBUILD_1_C[0])

# %%
print((Arr_TBUILD_1_JJA_C-Arr_TBUILD_0_JJA_C).mean(), (Arr_TBUILD_1_JJA_C-Arr_TBUILD_0_JJA_C).std())

# %%
print((Arr_TBUILD_1_C-Arr_TBUILD_0_C).mean(), (Arr_TBUILD_1_C-Arr_TBUILD_0_C).std())
# Out:
# -1.8167721019071694 0.02321101809215225

# %% [markdown]
# ## Year of reach threshold

# %%
Arr_HIA_U_0_JJA[Arr_HIA_U_0_JJA>27]
# Out:
# 22    27.138227
# 26    27.218397
# 28    27.262426
# 29    27.431425
# 30    27.217409
# 31    27.112631
# 33    27.513062
# 34    27.214211
# 35    27.698505
# 36    27.685282
# 37    27.659613
# 38    27.634132
# 39    28.011744
# 40    27.519598
# 41    28.337257
# 42    27.435265
# 43    28.148226
# 44    28.616432
# 45    28.656530
# 46    28.269062
# 47    28.691530
# 48    28.768370
# 49    28.028442
# 50    28.277164
# 51    28.880867
# 52    27.948690
# 53    28.777376
# 54    29.097338
# 55    28.807028
# 56    29.518705
# 57    29.441198
# 58    28.952999
# 59    29.145199
# 60    29.204588
# 61    29.492918
# 62    29.859997
# 63    29.598055
# 64    29.621758
# 65    30.398073
# 66    30.031069
# 67    29.767679
# 68    30.292122
# 69    30.576372
# 70    30.797663
# 71    30.175863
# 72    31.183481
# 73    30.449257
# 74    30.779482
# 75    30.842541
# 76    30.770889
# 77    31.329649
# 78    30.826813
# 79    31.958403
# 80    31.886217
# 81    31.718380
# ...

# %%
#Arr_HIA_U_0_JJA[28] # 2015+28 = 2043
Arr_HIA_U_0_JJA[22] # 2015+22 = 2037
# Out:
# 27.262426376342773

# %%
Arr_HIA_U_1_JJA[Arr_HIA_U_1_JJA>27]
# Out:
# 35    27.116133
# 36    27.101168
# 37    27.082832
# 38    27.054996
# 39    27.427870
# 41    27.753443
# 43    27.566238
# 44    28.025597
# 45    28.076509
# 46    27.684526
# 47    28.103529
# 48    28.191864
# 49    27.446728
# 50    27.693874
# 51    28.299116
# 52    27.369509
# 53    28.190821
# 54    28.513496
# 55    28.230907
# 56    28.938641
# 57    28.853165
# 58    28.370491
# 59    28.568560
# 60    28.624035
# 61    28.900089
# 62    29.277332
# 63    29.016901
# 64    29.035677
# 65    29.805840
# 66    29.451710
# 67    29.183470
# 68    29.710989
# 69    29.988567
# 70    30.213865
# 71    29.596334
# 72    30.607380
# 73    29.875154
# 74    30.194988
# 75    30.260414
# 76    30.192844
# 77    30.747698
# 78    30.240395
# 79    31.373352
# 80    31.290613
# 81    31.132530
# 82    30.579655
# 83    31.343927
# 84    31.056789
# Name: Arr_HIA_U_1_JJA, dtype: float64

# %%
Arr_HIA_U_1_JJA[35] # 2015+35 = 2050
# Out:
# 27.11613273620605

# %%
Arr_HIA_U_2_JJA[Arr_HIA_U_2_JJA>27]
# Out:
# 26    27.004698
# 28    27.024090
# 29    27.185442
# 33    27.233425
# 35    27.397398
# 36    27.374994
# 37    27.343382
# 38    27.307661
# 39    27.673594
# 40    27.177164
# 41    27.980433
# 42    27.075584
# 43    27.775358
# 44    28.228256
# 45    28.265909
# 46    27.866423
# 47    28.278971
# 48    28.352381
# 49    27.601572
# 50    27.840185
# 51    28.436279
# 52    27.497587
# 53    28.312090
# 54    28.624796
# 55    28.331951
# 56    29.031523
# 57    28.938463
# 58    28.447222
# 59    28.636583
# 60    28.686396
# 61    28.958075
# 62    29.327360
# 63    29.060419
# 64    29.074911
# 65    29.839832
# 66    29.479124
# 67    29.205647
# 68    29.728291
# 69    30.002157
# 70    30.223341
# 71    29.602789
# 72    30.611467
# 73    29.877316
# 74    30.196043
# 75    30.260738
# 76    30.192915
# 77    30.747772
# 78    30.240450
# 79    31.373423
# 80    31.290674
# 81    31.132589
# 82    30.579710
# 83    31.343981
# 84    31.056833
# ...

# %%
#Arr_HIA_U_2_JJA[28] # 2015+28 = 2043
Arr_HIA_U_2_JJA[26] # 2015+26 = 2041
# Out:
# 27.004697799682617

# %%
Arr_SWBGT_U_0_JJA[Arr_SWBGT_U_0_JJA>26.7]
# Out:
# 44    26.839361
# 45    26.905012
# 47    26.862719
# 48    27.072641
# 51    27.061501
# 53    26.949766
# 54    27.155361
# 55    27.005764
# 56    27.493046
# 57    27.471539
# 58    27.061508
# 59    27.282682
# 60    27.250736
# 61    27.375702
# 62    27.695475
# 63    27.579470
# 64    27.457270
# 65    27.984604
# 66    27.730408
# 67    27.573517
# 68    27.931570
# 69    28.037388
# 70    28.201677
# 71    27.711203
# 72    28.553970
# 73    27.972462
# 74    28.191336
# 75    28.163101
# 76    28.182318
# 77    28.580500
# 78    28.240799
# 79    28.949526
# 80    28.848618
# 81    28.842310
# 82    28.388887
# 83    28.903587
# 84    28.740225
# Name: Arr_SWBGT_U_0_JJA, dtype: float64

# %%
#Arr_SWBGT_U_0_JJA[50] # 2015+50 = 2065
Arr_SWBGT_U_0_JJA[44] # 2015+44 = 2059
# Out:
# 26.60857963562012

# %%
Arr_SWBGT_U_1_JJA[Arr_SWBGT_U_1_JJA>26.7]
# Out:
# 48    26.803608
# 51    26.789804
# 54    26.879576
# 55    26.728470
# 56    27.217955
# 57    27.196804
# 58    26.782183
# 59    27.008951
# 60    26.977074
# 61    27.094793
# 62    27.423243
# 63    27.304729
# 64    27.184053
# 65    27.708927
# 66    27.458378
# 67    27.293507
# 68    27.658596
# 69    27.760471
# 70    27.927588
# 71    27.434378
# 72    28.286335
# 73    27.698153
# 74    27.916441
# 75    27.891651
# 76    27.909966
# 77    28.311962
# 78    27.966349
# 79    28.677757
# 80    28.570217
# 81    28.571043
# 82    28.116966
# 83    28.632462
# 84    28.468170
# Name: Arr_SWBGT_U_1_JJA, dtype: float64

# %%
#Arr_SWBGT_U_1_JJA[54] # 2015+54 = 2069
Arr_SWBGT_U_1_JJA[48] # 2015+48 = 2063
# Out:
# 26.803607940673828

# %%
Arr_SWBGT_U_2_JJA[Arr_SWBGT_U_2_JJA>26.7]
# Out:
# 45    26.718323
# 48    26.876812
# 51    26.852758
# 53    26.727882
# 54    26.931477
# 55    26.776548
# 56    27.261660
# 57    27.236198
# 58    26.818764
# 59    27.041313
# 60    27.007103
# 61    27.122908
# 62    27.446888
# 63    27.326141
# 64    27.203007
# 65    27.725323
# 66    27.472267
# 67    27.305136
# 68    27.667635
# 69    27.767735
# 70    27.932703
# 71    27.438141
# 72    28.288641
# 73    27.699434
# 74    27.917063
# 75    27.891825
# 76    27.909996
# 77    28.311991
# 78    27.966377
# 79    28.677786
# 80    28.570240
# 81    28.571068
# 82    28.116991
# 83    28.632484
# 84    28.468189
# Name: Arr_SWBGT_U_2_JJA, dtype: float64

# %%
#Arr_SWBGT_U_2_JJA[53] # 2015+53 = 2068
Arr_SWBGT_U_2_JJA[45] # 2015+45 = 2060
# Out:
# 26.71832275390625

# %%
Arr_HUMIDEX_U_0_JJA[Arr_HUMIDEX_U_0_JJA>30]
# Out:
# 15    30.124702
# 16    30.174545
# 19    30.445156
# 20    30.097603
# 21    30.081617
#         ...
# 80    35.385555
# 81    35.297192
# 82    34.621780
# 83    35.439636
# 84    35.182880
# Name: Arr_HUMIDEX_U_0_JJA, Length: 68, dtype: float64

# %%
Arr_HUMIDEX_U_0_JJA[15] # 2015+15 = 2030
# Out:
# 30.12464904785156

# %%
Arr_HUMIDEX_U_1_JJA[Arr_HUMIDEX_U_1_JJA>30]
# Out:
# 22    30.260965
# 23    30.026049
# 25    30.003508
# 26    30.333735
# 28    30.328426
# 29    30.463757
# 30    30.248960
# 31    30.250198
# 33    30.516893
# 34    30.058994
# 35    30.694616
# 36    30.713369
# 37    30.645014
# 38    30.607862
# 39    31.021931
# 40    30.382471
# 41    31.293318
# 42    30.339334
# 43    31.112688
# 44    31.595741
# 45    31.673611
# 46    31.262779
# 47    31.634954
# 48    31.911407
# 49    31.030018
# 50    31.231808
# 51    31.912985
# 52    31.004259
# 53    31.787540
# 54    32.100430
# 55    31.866590
# 56    32.664810
# 57    32.600410
# 58    31.976643
# 59    32.302074
# 60    32.223518
# 61    32.500126
# 62    32.941158
# 63    32.793293
# 64    32.564255
# 65    33.468079
# 66    33.022652
# 67    32.820023
# 68    33.346394
# 69    33.555309
# 70    33.786812
# 71    33.047668
# 72    34.341766
# 73    33.440189
# 74    33.811798
# 75    33.728516
# 76    33.790188
# 77    34.371407
# 78    33.857754
# 79    35.011101
# ...

# %%
#Arr_HUMIDEX_U_1_JJA[25] # 2015+25 = 2040
Arr_HUMIDEX_U_1_JJA[22] # 2015+22 = 2037
# Out:
# 30.003507614135746

# %%
Arr_HUMIDEX_U_2_JJA[Arr_HUMIDEX_U_2_JJA>30]
# Out:
# 15    30.013351
# 16    30.057961
# 19    30.307163
# 22    30.592566
# 23    30.347277
#         ...
# 80    34.882092
# 81    34.806797
# 82    34.130993
# 83    34.949234
# 84    34.689991
# Name: Arr_HUMIDEX_U_2_JJA, Length: 65, dtype: float64

# %%
#Arr_HUMIDEX_U_2_JJA[21] # 2015+22 = 2036
Arr_HUMIDEX_U_2_JJA[15] # 2015+15 = 2030
# Out:
# 29.92543029785156

# %%
Arr_DISCOIS_U_0_JJA[Arr_DISCOIS_U_0_JJA>24]
# Out:
# 65    24.327213
# 68    24.187437
# 69    24.363817
# 70    24.441410
# 71    24.082247
# 72    24.732090
# 73    24.279322
# 74    24.530790
# 75    24.378775
# 76    24.486155
# 77    24.717093
# 78    24.504816
# 79    25.151310
# 80    25.144926
# 81    25.007965
# 82    24.685444
# 83    25.131041
# 84    25.009747
# Name: Arr_DISCOIS_U_0_JJA, dtype: float64

# %%
Arr_DISCOIS_U_0_JJA[65] # 2015+65 = 2080
# Out:
# 24.32719993591309

# %%
Arr_DISCOIS_U_1_JJA[Arr_DISCOIS_U_1_JJA>24]
# Out:
# 69    24.015270
# 70    24.097002
# 72    24.397961
# 74    24.185118
# 75    24.037828
# 76    24.145662
# 77    24.380411
# 78    24.159460
# 79    24.813305
# 80    24.795649
# 81    24.667484
# 82    24.344824
# 83    24.791183
# 84    24.666138
# Name: Arr_DISCOIS_U_1_JJA, dtype: float64

# %%
Arr_DISCOIS_U_1_JJA[69] # 2015+68 = 2084
# Out:
# 24.015270233154297

# %%
Arr_DISCOIS_U_2_JJA[Arr_DISCOIS_U_2_JJA>24]
# Out:
# 69    24.024237
# 70    24.103302
# 72    24.400751
# 74    24.185862
# 75    24.038044
# 76    24.145697
# 77    24.380447
# 78    24.159487
# 79    24.813339
# 80    24.795681
# 81    24.667511
# 82    24.344852
# 83    24.791210
# 84    24.666161
# Name: Arr_DISCOIS_U_2_JJA, dtype: float64

# %%
Arr_DISCOIS_U_2_JJA[69] # 2015+68 = 2084
# Out:
# 24.02423667907715

# %%
Arr_TBUILD_0_JJA_C[Arr_TBUILD_0_JJA_C>28]
# Out:
# 44    28.257623
# 45    28.075677
# 47    28.346735
# 48    28.003168
# 50    28.096246
# 51    28.064050
# 53    28.429712
# 54    28.472406
# 55    28.369409
# 56    28.844476
# 57    28.697443
# 58    28.567743
# 59    28.531061
# 60    28.359949
# 61    28.992181
# 62    28.787714
# 63    28.893610
# 64    28.572076
# 65    29.476923
# 66    28.906702
# 67    29.159479
# 68    29.119501
# 69    29.507318
# 70    29.507349
# 71    29.248834
# 72    29.638086
# 73    29.290216
# 74    29.663507
# 75    29.387476
# 76    29.573999
# 77    29.545892
# 78    29.510339
# 79    30.178217
# 80    30.312494
# 81    29.900720
# 82    29.798120
# 83    30.271234
# 84    30.119043
# Name: Arr_TBUILD_0_JJA_C, dtype: float64

# %%
#Arr_TBUILD_0_JJA_C[50] # 2015+50 = 2065
Arr_TBUILD_0_JJA_C[44] # 2015+44 = 2059
# Out:
# 28.257623291015648

# %%
Arr_TBUILD_1_JJA_C[Arr_TBUILD_1_JJA_C>28]
# Out:
# 79    28.185297
# 80    28.275323
# 83    28.231012
# 84    28.060419
# Name: Arr_TBUILD_1_JJA_C, dtype: float64

# %%
Arr_TBUILD_1_JJA_C[79] # 2015+79 = 2094
# Out:
# 28.1852966308594

# %%
Arr_TBUILD_2_JJA_C[Arr_TBUILD_2_JJA_C>28]
# Out:
# 79    28.185358
# 80    28.275385
# 83    28.231012
# 84    28.060449
# Name: Arr_TBUILD_2_JJA_C, dtype: float64

# %%
Arr_TBUILD_2_JJA_C[79] # 2015+79 = 2094
# Out:
# 28.185357666015648

# %%
Arr_TBUILD_0_DJF_C[Arr_TBUILD_0_DJF_C>19]
# Out:
# 0     19.194116
# 1     19.179285
# 2     19.097498
# 3     19.003839
# 4     19.365717
#         ...
# 80    21.318140
# 81    20.993219
# 82    21.415674
# 83    21.452203
# 84    21.563379
# Name: Arr_TBUILD_0_DJF_C, Length: 85, dtype: float64

# %%
Arr_TBUILD_0_DJF_C[0] # 2015
# Out:
# 19.198449707031276

# %%
Arr_TBUILD_1_DJF_C[Arr_TBUILD_1_DJF_C>19]
# Out:
# 47    19.284357
# 53    19.181329
# 56    19.167627
# 59    19.101953
# 61    19.474817
# 63    19.079889
# 64    19.277368
# 65    19.581781
# 67    19.375696
# 68    19.268060
# 69    19.651880
# 70    19.339655
# 71    19.757257
# 72    19.365381
# 73    19.435663
# 74    20.024561
# 75    19.378656
# 76    19.835046
# 77    19.514673
# 78    19.844110
# 79    19.573450
# 80    19.906885
# 81    19.567743
# 82    20.004266
# 83    20.051904
# 84    20.123468
# Name: Arr_TBUILD_1_DJF_C, dtype: float64

# %%
Arr_TBUILD_1_DJF_C[55:65]
# Out:
# 55    18.732385
# 56    19.167627
# 57    18.879388
# 58    18.923730
# 59    19.101953
# 60    18.839471
# 61    19.474817
# 62    18.885309
# 63    19.079889
# 64    19.277368
# Name: Arr_TBUILD_1_DJF_C, dtype: float64

# %%
Arr_TBUILD_1_DJF_C[63] # 2015 + 63 = 2078
# Out:
# 19.284356689453148

# %%
Arr_TBUILD_2_DJF_C[Arr_TBUILD_2_DJF_C>19]
# Out:
# 0     19.154169
# 1     19.121912
# 2     19.019495
# 4     19.247858
# 8     19.172968
# 10    19.111505
# 11    19.086572
# 12    19.183191
# 14    19.195306
# 15    19.182581
# 18    19.315881
# 21    19.089929
# 24    19.087366
# 28    19.229974
# 30    19.074487
# 32    19.219141
# 34    19.124689
# 36    19.220300
# 40    19.117548
# 42    19.020685
# 43    19.048975
# 44    19.422845
# 47    19.672937
# 50    19.206995
# 53    19.449335
# 54    19.240717
# 56    19.385248
# 57    19.081812
# 58    19.100641
# 59    19.262842
# 61    19.597467
# 63    19.174554
# 64    19.356714
# 65    19.646112
# 66    19.027795
# 67    19.414301
# 68    19.296930
# 69    19.670984
# 70    19.351801
# 71    19.763055
# 72    19.368402
# 73    19.436945
# 74    20.025140
# 75    19.378778
# 76    19.835107
# 77    19.514734
# 78    19.844171
# 79    19.573541
# 80    19.906976
# 81    19.567834
# 82    20.004327
# 83    20.051935
# 84    20.172723
# Name: Arr_TBUILD_2_DJF_C, dtype: float64

# %%
Arr_TBUILD_2_DJF_C[0] # 2015
# Out:
# 19.154168701171898
