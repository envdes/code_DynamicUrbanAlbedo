# %% [markdown]
# # Temperature comparison figure
# - This script is used to export CUHI, SUHI, SWBGT, TBUILD variables at the landunit level;
# - Simulations: CNTL, ROOF_DA, IMPRAOD_DA, WALL_DA;

# %%
import pandas as pd
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt
from matplotlib.ticker import MultipleLocator

# %%
df0 = pd.read_csv('export_hete_temperature0.csv')
for column_name in df0.columns:
    globals()[column_name] = df0[column_name]   

df2 = pd.read_csv('export_hete_temperature2.csv')
for column_name in df2.columns:
    globals()[column_name] = df2[column_name] 

df3 = pd.read_csv('export_hete_temperature3.csv')
for column_name in df3.columns:
    globals()[column_name] = df3[column_name]  

df5 = pd.read_csv('export_hete_temperature5.csv')
for column_name in df5.columns:
    globals()[column_name] = df5[column_name]

# %%
cuhi = [Arr_CUHI_0, Arr_CUHI_2, Arr_CUHI_3, Arr_CUHI_5]
cuhi_jja = [Arr_CUHI_0_JJA, Arr_CUHI_2_JJA, Arr_CUHI_3_JJA, Arr_CUHI_5_JJA]
cuhi_djf = [Arr_CUHI_0_DJF, Arr_CUHI_2_DJF, Arr_CUHI_3_DJF, Arr_CUHI_5_DJF]

suhi = [Arr_SUHI_0, Arr_SUHI_2, Arr_SUHI_3, Arr_SUHI_5]
suhi_jja = [Arr_SUHI_0_JJA, Arr_SUHI_2_JJA, Arr_SUHI_3_JJA, Arr_SUHI_5_JJA]
suhi_djf = [Arr_SUHI_0_DJF, Arr_SUHI_2_DJF, Arr_SUHI_3_DJF, Arr_SUHI_5_DJF]

SWBGT = [Arr_SWBGT_U_0, Arr_SWBGT_U_2, Arr_SWBGT_U_3, Arr_SWBGT_U_5]
SWBGT_jja = [Arr_SWBGT_U_0_JJA, Arr_SWBGT_U_2_JJA, Arr_SWBGT_U_3_JJA, Arr_SWBGT_U_5_JJA]
SWBGT_djf = [Arr_SWBGT_U_0_DJF, Arr_SWBGT_U_2_DJF, Arr_SWBGT_U_3_DJF, Arr_SWBGT_U_5_DJF]

tbuild = [Arr_TBUILD_0, Arr_TBUILD_2, Arr_TBUILD_3, Arr_TBUILD_5]
tbuild_jja = [Arr_TBUILD_0_JJA, Arr_TBUILD_2_JJA, Arr_TBUILD_3_JJA, Arr_TBUILD_5_JJA]
tbuild_djf = [Arr_TBUILD_0_DJF, Arr_TBUILD_2_DJF, Arr_TBUILD_3_DJF, Arr_TBUILD_5_DJF]

# %%
data = [[cuhi, cuhi_jja, cuhi_djf], 
        [suhi, suhi_jja, suhi_djf], 
        [SWBGT, SWBGT_jja, SWBGT_djf], 
        [tbuild, tbuild_jja, tbuild_djf]]

# %%
delta_cuhi = [Arr_CUHI_2-Arr_CUHI_0, Arr_CUHI_3-Arr_CUHI_0, Arr_CUHI_5-Arr_CUHI_0]
delta_cuhi_jja = [Arr_CUHI_2_JJA-Arr_CUHI_0_JJA, Arr_CUHI_3_JJA-Arr_CUHI_0_JJA, Arr_CUHI_5_JJA-Arr_CUHI_0_JJA]
delta_cuhi_djf = [Arr_CUHI_2_DJF-Arr_CUHI_0_DJF, Arr_CUHI_3_DJF-Arr_CUHI_0_DJF, Arr_CUHI_5_DJF-Arr_CUHI_0_DJF]

delta_suhi = [Arr_SUHI_2-Arr_SUHI_0, Arr_SUHI_3-Arr_SUHI_0, Arr_SUHI_5-Arr_SUHI_0]
delta_suhi_jja = [Arr_SUHI_2_JJA-Arr_SUHI_0_JJA, Arr_SUHI_3_JJA-Arr_SUHI_0_JJA, Arr_SUHI_5_JJA-Arr_SUHI_0_JJA]
delta_suhi_djf = [Arr_SUHI_2_DJF-Arr_SUHI_0_DJF, Arr_SUHI_3_DJF-Arr_SUHI_0_DJF, Arr_SUHI_5_DJF-Arr_SUHI_0_DJF]

delta_SWBGT = [Arr_SWBGT_U_2-Arr_SWBGT_U_0, Arr_SWBGT_U_3-Arr_SWBGT_U_0, Arr_SWBGT_U_5-Arr_SWBGT_U_0]
delta_SWBGT_jja = [Arr_SWBGT_U_2_JJA-Arr_SWBGT_U_0_JJA, Arr_SWBGT_U_3_JJA-Arr_SWBGT_U_0_JJA, Arr_SWBGT_U_5_JJA-Arr_SWBGT_U_0_JJA]
delta_SWBGT_djf = [Arr_SWBGT_U_2_DJF-Arr_SWBGT_U_0_DJF, Arr_SWBGT_U_3_DJF-Arr_SWBGT_U_0_DJF, Arr_SWBGT_U_5_DJF-Arr_SWBGT_U_0_DJF]

delta_tbuild = [Arr_TBUILD_2-Arr_TBUILD_0, Arr_TBUILD_3-Arr_TBUILD_0, Arr_TBUILD_5-Arr_TBUILD_0]
delta_tbuild_jja = [Arr_TBUILD_2_JJA-Arr_TBUILD_0_JJA, Arr_TBUILD_3_JJA-Arr_TBUILD_0_JJA, Arr_TBUILD_5_JJA-Arr_TBUILD_0_JJA]
delta_tbuild_djf = [Arr_TBUILD_2_DJF-Arr_TBUILD_0_DJF, Arr_TBUILD_3_DJF-Arr_TBUILD_0_DJF, Arr_TBUILD_5_DJF-Arr_TBUILD_0_DJF]

# %%
delta_data = [[delta_cuhi, delta_cuhi_jja, delta_cuhi_djf], 
        [delta_suhi, delta_suhi_jja, delta_suhi_djf], 
        [delta_SWBGT, delta_SWBGT_jja, delta_SWBGT_djf], 
        [delta_tbuild, delta_tbuild_jja, delta_tbuild_djf]]

# %%
# drawing
linewidth = 0.5
linewidth2 = 1
fontsize = 6
start_year = 2015
end_year = 2100
labelcolor = '#6b6b6b'
lc1 = '#6e1913'
lc2 = '#a42018'
lc3 = '#f62d18'
lc4 = '#d97c26'
lc5 = '#ff912b'
lc6 = '#30b5d6'
lc7 = '#28ac92'
lc8 = '#123264'
lc9 = '#05101f'
lc10 = '#952cc6'
lc11 = '#2c4dc6'
lc12 = '#5fc62c'
minor_locator = MultipleLocator(10)
specific_years = [2015, 2050, 2099]
alpha=0.075
xwidth = 0.75
length = 4
labelfont = 6
pad=1
handletextpad=0.5
l = ['CNTL', 'ROOF_DA', 'IMPROAD_DA', 'WALL_DA']
lc = [lc1, lc3, lc7, lc4, lc9, lc5, lc2]
t = [['(a) CUHII - ANN','(b) CUHII - JJA','(c) CUHII - DJF'],
     ['(d) SUHII - ANN', '(e) SUHII - JJA', '(f) SUHII - DJF'],
     ['(g) sWBGT - ANN', '(h) sWBGT - JJA', '(i) sWBGT - DJF'],
     ['(j) TBUILD - ANN', '(k) TBUILD - JJA', '(l) TBUILD - DJF']]
ymin1 = -2
ymax1 = 2
ymin3 = 15
ymax3 = 32
ymin4 = 18
ymax4 = 32
ymin_list = [ymin1,ymin1, ymin3,ymin4]
ymax_list = [ymax1,ymax1,ymax3,ymax4]
delta_ymax = [0.5, 0.5, 2, 1.8]
tbuild_l = 19
tbuild_u = 28
sizes = 2
year_offset = 20
yloc = 20
scatter = [2043, 2044, 2048]
scatter2 = [2059, 2060, 2059, 2059]

# %%
fig, axes = plt.subplots(nrows=4, ncols=3, figsize=(5.5, 4))
for i in range(4):
    ymin, ymax = ymin_list[i], ymax_list[i]
    for j in range(3):
        for m in range(4):
            axes[i,j].plot(time, data[i][j][m], linewidth=linewidth,label=l[m], color = lc[m])
            if m ==3:
               axes[i,j].fill_betweenx([ymin, ymax],2021, 2040, color=lc9, alpha=alpha, label='Near-term', edgecolor='none')
               axes[i,j].fill_betweenx([ymin, ymax],2041, 2060, color=lc5, alpha=alpha, label='Mid-term', edgecolor='none')
               axes[i,j].fill_betweenx([ymin, ymax],2081, 2100, color=lc2, alpha=alpha, label='Long-term', edgecolor='none') 
               for n in range(3):
                   delta_value = delta_data[i][j][n][84]
                   if 0<delta_value<=0.1 or -0.1<=delta_value<0:
                       axes[i,j].text(2015 + n*26,ymax-delta_ymax[i],'Δ: ' + str("{:.2f}".format(delta_value))+'℃ ', fontsize=labelfont, color=lc[n+1])
                   else:
                       axes[i,j].text(2015 + n*26,ymax-delta_ymax[i],'Δ: ' + str("{:.1f}".format(delta_value))+'℃ ', fontsize=labelfont, color=lc[n+1])
               #axes[i,j].text(2015,ymax-delta_ymax[i],'Δ: ' + str("{:.2f}".format(delta_data[i][j][m-3][84]))+'℃ ', fontsize=labelfont, color=lc[m-2])
               #axes[i,j].text(2041,ymax-delta_ymax[i],'Δ: ' + str("{:.2f}".format(delta_data[i][j][m-2][84]))+'℃ ', fontsize=labelfont, color=lc[m-1]) 
               #axes[i,j].text(2067,ymax-delta_ymax[i],'Δ: ' + str("{:.2f}".format(delta_data[i][j][m-1][84]))+'℃', fontsize=labelfont, color=lc[m]) 
                       
        axes[i,j].set_xlim(start_year,2099)
        axes[i,j].tick_params(axis='y', which='major', left=False, right=False, labelleft=True, labelcolor=labelcolor,labelsize=labelfont, color = labelcolor, pad = pad, width = xwidth, length = 0)
        axes[i,j].tick_params(axis='x', which='minor', top=False, bottom=True, labelbottom=True, labelcolor=labelcolor,labelsize=labelfont, color = labelcolor,  pad = pad, width = xwidth, length = length/2)
        axes[i,j].tick_params(axis='x', which='major', top=False, bottom=True, labelbottom=True, labelcolor=labelcolor,labelsize=labelfont, color = labelcolor, pad = pad, width = xwidth, length = length)
        axes[i,j].spines['left'].set_visible(False)
        axes[i,j].spines['top'].set_visible(False)
        axes[i,j].spines['right'].set_visible(False)
        axes[i,j].spines['bottom'].set_color(labelcolor)
        axes[i,j].spines['bottom'].set_color(labelcolor)
        axes[i,j].xaxis.set_minor_locator(minor_locator)
        axes[i,j].set_xticks(specific_years)
        axes[i,j].grid(True, which='major', axis='y',linestyle='--',linewidth=linewidth, alpha=0.5)
        axes[i,j].set_ylim(ymin, ymax)
        axes[i,j].set_title(t[i][j],fontsize = fontsize,color=labelcolor,pad=4)
        axes[i,j].set_ylabel('℃', labelpad=5, rotation=0, ha='center', fontsize=labelfont,color=labelcolor)
        axes[i,j].yaxis.set_label_coords(0, 1.06)
        
lines, labels = axes[0,0].get_legend_handles_labels()

for m in [0,1,2]:
    axes[1, m].hlines(y=0, xmin=min(time), xmax=max(time), linewidth=linewidth, color=labelcolor, linestyle='--')
    axes[1, m].text(max(time), 0, '0℃', verticalalignment='center', fontsize=labelfont, color=labelcolor)
    axes[1, m].scatter(scatter[m-3], 0, color=lc3, s=sizes)
    axes[1, m].text(scatter[m-3]+1, 0.1, str(scatter[m-3]), fontsize=labelfont, color=lc3)

axes[2, 1].hlines(y=26.7, xmin=min(time), xmax=max(time), linewidth=linewidth, color=labelcolor, linestyle='--')
axes[2, 1].text(max(time), 26.7, '26.7℃', verticalalignment='center', fontsize=labelfont, color=labelcolor)
for n in range(4):
    axes[2, 1].scatter(scatter2[n], 26.7, color=lc[n], s=sizes)
    axes[2, 1].text(2015 + year_offset*n, yloc, '•' + str(scatter2[n]), fontsize=labelfont, color=lc[n])

axes[3,1].hlines(y=tbuild_u , xmin=min(time), xmax=max(time), linewidth=linewidth, color=labelcolor, linestyle='--')
axes[3,1].text(max(time), tbuild_u , '28℃', verticalalignment='center', fontsize=labelfont, color=labelcolor)
axes[3,1].scatter(2059, tbuild_u , color=lc1, s=sizes)
axes[3,1].scatter(2094, tbuild_u , color=lc3, s=sizes)
axes[3,1].scatter(2059, tbuild_u , color=lc7, s=sizes)
axes[3,1].scatter(2071, tbuild_u , color=lc4, s=sizes)
axes[3,1].text(2015, yloc, '•2059', fontsize=labelfont, color=lc1)
axes[3,1].text(2015 + year_offset, yloc, '•2094', fontsize=labelfont, color=lc3)
axes[3,1].text(2015 + year_offset*2, yloc, '•2059', fontsize=labelfont, color=lc7)
axes[3,1].text(2015 + year_offset*3, yloc, '•2071', fontsize=labelfont, color=lc4)

axes[3,2].hlines(y=tbuild_l , xmin=min(time), xmax=max(time), linewidth=linewidth, color=labelcolor, linestyle='--')
axes[3,2].text(max(time), tbuild_l , '19℃', verticalalignment='center', fontsize=labelfont, color=labelcolor)

new_order = [ 0, 4, 1, 5, 2, 6, 3]
new_lines = [lines[i] for i in new_order]
new_labels = [labels[i] for i in new_order]
new_lc = [lc[i] for i in new_order]
legend = fig.legend(new_lines, new_labels, bbox_to_anchor=(0.5, -0.01), loc='lower center',frameon=False,handletextpad=handletextpad,fontsize=labelfont, ncol = 4)
for i, text in enumerate(legend.get_texts()):
    text.set_color(new_lc[i])
    
plt.subplots_adjust(left=0.0325, right=0.96, bottom=0.12, top=0.96, wspace=0.22, hspace= 0.55)        
fig.savefig('hete_tem.png', dpi=300)
fig.savefig('hete_tem.pdf', dpi=600)

# %% [markdown]
# ## Year of reaching threshold

# %%
Arr_TBUILD_0_JJA[Arr_TBUILD_0_JJA>28]
# Out:
# 44    28.257631
# 45    28.075703
# 47    28.346748
# 48    28.003164
# 50    28.096268
# 51    28.064053
# 53    28.429724
# 54    28.472414
# 55    28.369419
# 56    28.844473
# 57    28.697453
# 58    28.567739
# 59    28.531071
# 60    28.359968
# 61    28.992188
# 62    28.787710
# 63    28.893606
# 64    28.572088
# 65    29.476938
# 66    28.906693
# 67    29.159529
# 68    29.119488
# 69    29.507313
# 70    29.507372
# 71    29.248829
# 72    29.638052
# 73    29.290201
# 74    29.663517
# 75    29.387480
# 76    29.574032
# 77    29.545856
# 78    29.510313
# 79    30.178225
# 80    30.312500
# 81    29.900724
# 82    29.798080
# 83    30.271219
# 84    30.119085
# Name: Arr_TBUILD_0_JJA, dtype: float64

# %%
#Arr_TBUILD_0_JJA[50] # 2015+50 = 2065
Arr_TBUILD_0_JJA[44] # 2015+44 = 2059
# Out:
# 28.096267700195312

# %%
Arr_TBUILD_2_JJA[Arr_TBUILD_2_JJA>28]
# Out:
# 79    28.185333
# 80    28.275394
# 83    28.231077
# 84    28.060467
# Name: Arr_TBUILD_2_JJA, dtype: float64

# %%
Arr_TBUILD_2_JJA[79] # 2015+79 = 2094
# Out:
# 28.185333251953125

# %%
Arr_TBUILD_3_JJA[Arr_TBUILD_3_JJA>28]
# Out:
# 44    28.297588
# 45    28.117479
# 47    28.389723
# 48    28.046936
# 50    28.142223
# 51    28.110403
# 53    28.478260
# 54    28.521282
# 55    28.420280
# 56    28.895248
# 57    28.749346
# 58    28.620996
# 59    28.584890
# 60    28.414780
# 61    29.046818
# 62    28.843760
# 63    28.950350
# 64    28.629333
# 65    29.534838
# 66    28.965559
# 67    29.219997
# 68    29.181013
# 69    29.568789
# 70    29.570995
# 71    29.312056
# 72    29.701670
# 73    29.356672
# 74    29.729113
# 75    29.453388
# 76    29.641027
# 77    29.613039
# 78    29.577480
# 79    30.244041
# 80    30.377853
# 81    29.968603
# 82    29.864416
# 83    30.335907
# 84    30.183792
# Name: Arr_TBUILD_3_JJA, dtype: float64

# %%
#Arr_TBUILD_3_JJA[50] # 2015+50 = 2065
Arr_TBUILD_3_JJA[44] # 2015+44 = 2059
# Out:
# 28.142223358154297

# %%
Arr_TBUILD_5_JJA[Arr_TBUILD_5_JJA>28]
# Out:
# 56    28.046276
# 61    28.147766
# 63    28.047085
# 65    28.616478
# 66    28.077625
# 67    28.299620
# 68    28.270945
# 69    28.658714
# 70    28.643597
# 71    28.405731
# 72    28.807692
# 73    28.444519
# 74    28.808630
# 75    28.550001
# 76    28.730471
# 77    28.710011
# 78    28.664486
# 79    29.347073
# 80    29.469595
# 81    29.050703
# 82    28.960350
# 83    29.432850
# 84    29.274641
# Name: Arr_TBUILD_5_JJA, dtype: float64

# %%
#Arr_TBUILD_5_JJA[63] # 2015+63 = 2078
Arr_TBUILD_5_JJA[56] # 2015+56 = 2071
# Out:
# 28.04708480834961

# %%
Arr_TBUILD_5_DJF[0]
# Out:
# 19.17892074584961

# %%
#Arr_SWBGT_U_0_JJA[49:53]
Arr_SWBGT_U_0_JJA[Arr_SWBGT_U_0_JJA>26.7]
# Out:
# 44    26.839361
# 45    26.905012
# 47    26.862719
# 48    27.072641
# 51    27.061501
# 53    26.949766
# 54    27.155361
# 55    27.005764
# 56    27.493046
# 57    27.471539
# 58    27.061508
# 59    27.282682
# 60    27.250736
# 61    27.375702
# 62    27.695475
# 63    27.579470
# 64    27.457270
# 65    27.984604
# 66    27.730408
# 67    27.573517
# 68    27.931570
# 69    28.037388
# 70    28.201677
# 71    27.711203
# 72    28.553970
# 73    27.972462
# 74    28.191336
# 75    28.163101
# 76    28.182318
# 77    28.580500
# 78    28.240799
# 79    28.949526
# 80    28.848618
# 81    28.842310
# 82    28.388887
# 83    28.903587
# 84    28.740225
# Name: Arr_SWBGT_U_0_JJA, dtype: float64

# %%
#Arr_SWBGT_U_0_JJA[50] - 26.7 # 2015 + 50 = 2065
Arr_SWBGT_U_0_JJA[44] # 2015 + 44 = 2059
# Out:
# 26.8393611907959

# %%
#Arr_SWBGT_U_2_JJA[49:55]
Arr_SWBGT_U_2_JJA[Arr_SWBGT_U_2_JJA>26.7]
# Out:
# 45    26.718323
# 48    26.876812
# 51    26.852758
# 53    26.727882
# 54    26.931477
# 55    26.776548
# 56    27.261660
# 57    27.236198
# 58    26.818764
# 59    27.041313
# 60    27.007103
# 61    27.122908
# 62    27.446888
# 63    27.326141
# 64    27.203007
# 65    27.725323
# 66    27.472267
# 67    27.305136
# 68    27.667635
# 69    27.767735
# 70    27.932703
# 71    27.438141
# 72    28.288641
# 73    27.699434
# 74    27.917063
# 75    27.891825
# 76    27.909996
# 77    28.311991
# 78    27.966377
# 79    28.677786
# 80    28.570240
# 81    28.571068
# 82    28.116991
# 83    28.632484
# 84    28.468189
# Name: Arr_SWBGT_U_2_JJA, dtype: float64

# %%
#Arr_SWBGT_U_2_JJA[53] - 26.7 # 2015 + 53 = 2068
Arr_SWBGT_U_2_JJA[45] # 2015 + 45 = 2060
# Out:
# 26.71832275390625

# %%
#Arr_SWBGT_U_3_JJA[49:55]
Arr_SWBGT_U_3_JJA[Arr_SWBGT_U_3_JJA>26.7]
# Out:
# 44    26.817963
# 45    26.883701
# 47    26.840111
# 48    27.050129
# 51    27.037273
# 53    26.924212
# 54    27.129444
# 55    26.979223
# 56    27.466127
# 57    27.444267
# 58    27.033375
# 59    27.254641
# 60    27.222223
# 61    27.345987
# 62    27.665901
# 63    27.549156
# 64    27.426802
# 65    27.953171
# 66    27.699289
# 67    27.540625
# 68    27.898834
# 69    28.003839
# 70    28.167971
# 71    27.676674
# 72    28.520071
# 73    27.937515
# 74    28.155565
# 75    28.127073
# 76    28.146236
# 77    28.544836
# 78    28.204437
# 79    28.913486
# 80    28.811535
# 81    28.806124
# 82    28.352459
# 83    28.867336
# 84    28.703499
# Name: Arr_SWBGT_U_3_JJA, dtype: float64

# %%
#Arr_SWBGT_U_3_JJA[53] - 26.7
Arr_SWBGT_U_3_JJA[44] # 2015 + 44 = 2059
# Out:
# 26.81796264648437

# %%
#Arr_SWBGT_U_5_JJA[49:55]
Arr_SWBGT_U_5_JJA[Arr_SWBGT_U_5_JJA>26.7]
# Out:
# 44    26.786619
# 45    26.852558
# 47    26.806379
# 48    27.017754
# 51    27.003044
# 53    26.885431
# 54    27.090303
# 55    26.938892
# 56    27.425070
# 57    27.403023
# 58    26.990509
# 59    27.212629
# 60    27.181814
# 61    27.302641
# 62    27.624971
# 63    27.506725
# 64    27.386133
# 65    27.910038
# 66    27.659441
# 67    27.498663
# 68    27.860456
# 69    27.963253
# 70    28.129120
# 71    27.638018
# 72    28.482969
# 73    27.900311
# 74    28.117815
# 75    28.091797
# 76    28.109369
# 77    28.510082
# 78    28.167431
# 79    28.876648
# 80    28.774216
# 81    28.771179
# 82    28.316053
# 83    28.830790
# 84    28.666376
# Name: Arr_SWBGT_U_5_JJA, dtype: float64

# %%
#Arr_SWBGT_U_5_JJA[53] - 26.7
Arr_SWBGT_U_5_JJA[44] # 2015 + 44 = 2059
# Out:
# 0.18543128967285227

# %% [markdown]
# ## Data description

# %%
print(cuhi[0][84]-cuhi[1][84])
print(cuhi[0][84]-cuhi[2][84])
print(cuhi[0][84]-cuhi[3][84])
# Out:
# 0.5193293988704681
# 0.04999852180480957
# 0.16489410400390625

# %%
print(suhi[0][84]-suhi[1][84])
print(suhi[0][84]-suhi[2][84])
print(suhi[0][84]-suhi[3][84])
# Out:
# 2.712741255760193
# 0.15825486183166482
# 0.46490514278411843

# %%
print(Arr_TBUILD_2[0]-273.15, Arr_TBUILD_2[84]-273.15)
# Out:
# 22.749291992187523 23.931512451171898

# %%
print(Arr_TBUILD_0[0]-273.15, Arr_TBUILD_0[84]-273.15)
# Out:
# 22.775598144531273 25.788171386718773

# %%
print(Arr_TBUILD_0_JJA[84]-Arr_TBUILD_2_JJA[84])
print(Arr_TBUILD_0_DJF[84]-Arr_TBUILD_2_DJF[84])
# Out:
# 2.058563232421875
# 1.43988037109375

# %%
print(Arr_TBUILD_3[84]-Arr_TBUILD_0[84])
# Out:
# 0.051666259765625

# %%
print(Arr_CUHI_0_JJA[84]-Arr_CUHI_5_JJA[84])
print(Arr_CUHI_0_DJF[84]-Arr_CUHI_5_DJF[84])
# Out:
# 0.17467421293258667
# 0.12843585014343267

# %%
print((Arr_TBUILD_0 - Arr_TBUILD_5).max())
# Out:
# 0.7349662780761719

# %%
print(Arr_SUHI_0[84])
# Out:
# 1.2245887517929075

# %%
Arr_TBUILD_0_JJA[50] # 2015 + 50 = 2065
# Out:
# 28.096267700195312

# %%
Arr_TBUILD_2_JJA[79] # 2015 + 79 = 2094
# Out:
# 28.185333251953125

# %%
Arr_TBUILD_3_JJA[50] # 2015 + 50 = 2065
# Out:
# 28.142223358154297

# %%
Arr_TBUILD_5_JJA[63] # 2015 + 63 = 2078
# Out:
# 28.04708480834961

# %% [markdown]
# # Regression

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
import statsmodels.api as sm

# %%
rf = pd.read_csv('alb_dynroof.csv')
for column_name in rf.columns:
    globals()[column_name] = rf[column_name]  

wl = pd.read_csv('alb_dynwall.csv')
for column_name in wl.columns:
    globals()[column_name] = wl[column_name]

rd = pd.read_csv('alb_dynrd.csv')
for column_name in rd.columns:
    globals()[column_name] = rd[column_name]

# %%
df = pd.DataFrame(Arr_CUHI_2)
x = rf[['alb']]
y = df['Arr_CUHI_2']
model = LinearRegression()
model.fit(x, y)
slope = model.coef_[0]  
intercept = model.intercept_  
y_pred = model.predict(x)
r2 = r2_score(y, y_pred)

x_with_intercept = sm.add_constant(x)
model_stats = sm.OLS(y, x_with_intercept).fit()
print(model_stats.summary())
print(f"Slope (Coefficient for 'time'): {slope}")
print(f"Intercept: {intercept}")
print(f"R-squared: {r2}")
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:             Arr_CUHI_2   R-squared:                       0.988
# Model:                            OLS   Adj. R-squared:                  0.988
# Method:                 Least Squares   F-statistic:                     6760.
# Date:                Fri, 15 Mar 2024   Prob (F-statistic):           2.65e-81
# Time:                        14:24:44   Log-Likelihood:                 211.11
# No. Observations:                  85   AIC:                            -418.2
# Df Residuals:                      83   BIC:                            -413.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.0365      0.008    135.964      0.000       1.021       1.052
# ...

# %%
df = pd.DataFrame(Arr_SUHI_2)
x = rf[['alb']]
y = df['Arr_SUHI_2']
model = LinearRegression()
model.fit(x, y)
slope = model.coef_[0]  
intercept = model.intercept_  
y_pred = model.predict(x)
r2 = r2_score(y, y_pred)

x_with_intercept = sm.add_constant(x)
model_stats = sm.OLS(y, x_with_intercept).fit()
print(model_stats.summary())
print(f"Slope (Coefficient for 'time'): {slope}")
print(f"Intercept: {intercept}")
print(f"R-squared: {r2}")
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:             Arr_SUHI_2   R-squared:                       0.999
# Model:                            OLS   Adj. R-squared:                  0.999
# Method:                 Least Squares   F-statistic:                 7.744e+04
# Date:                Fri, 15 Mar 2024   Prob (F-statistic):          4.70e-125
# Time:                        14:32:52   Log-Likelihood:                 181.29
# No. Observations:                  85   AIC:                            -358.6
# Df Residuals:                      83   BIC:                            -353.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          2.4359      0.011    224.986      0.000       2.414       2.457
# ...

# %%
df = pd.DataFrame(Arr_CUHI_3)
x = rd[['alb']]
y = df['Arr_CUHI_3']
model = LinearRegression()
model.fit(x, y)
slope = model.coef_[0]  
intercept = model.intercept_  
y_pred = model.predict(x)
r2 = r2_score(y, y_pred)

x_with_intercept = sm.add_constant(x)
model_stats = sm.OLS(y, x_with_intercept).fit()
print(model_stats.summary())
print(f"Slope (Coefficient for 'time'): {slope}")
print(f"Intercept: {intercept}")
print(f"R-squared: {r2}")
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:             Arr_CUHI_3   R-squared:                       0.897
# Model:                            OLS   Adj. R-squared:                  0.896
# Method:                 Least Squares   F-statistic:                     721.3
# Date:                Fri, 15 Mar 2024   Prob (F-statistic):           1.07e-42
# Time:                        14:34:09   Log-Likelihood:                 266.64
# No. Observations:                  85   AIC:                            -529.3
# Df Residuals:                      83   BIC:                            -524.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.7869      0.003    255.526      0.000       0.781       0.793
# ...

# %%
df = pd.DataFrame(Arr_SUHI_3)
x = rd[['alb']]
y = df['Arr_SUHI_3']
model = LinearRegression()
model.fit(x, y)
slope = model.coef_[0]  
intercept = model.intercept_  
y_pred = model.predict(x)
r2 = r2_score(y, y_pred)

x_with_intercept = sm.add_constant(x)
model_stats = sm.OLS(y, x_with_intercept).fit()
print(model_stats.summary())
print(f"Slope (Coefficient for 'time'): {slope}")
print(f"Intercept: {intercept}")
print(f"R-squared: {r2}")
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:             Arr_SUHI_3   R-squared:                       0.905
# Model:                            OLS   Adj. R-squared:                  0.904
# Method:                 Least Squares   F-statistic:                     794.5
# Date:                Fri, 15 Mar 2024   Prob (F-statistic):           2.87e-44
# Time:                        14:34:20   Log-Likelihood:                 201.79
# No. Observations:                  85   AIC:                            -399.6
# Df Residuals:                      83   BIC:                            -394.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.2971      0.007    196.400      0.000       1.284       1.310
# ...

# %%
df = pd.DataFrame(Arr_CUHI_5)
x = wl[['alb']]
y = df['Arr_CUHI_5']
model = LinearRegression()
model.fit(x, y)
slope = model.coef_[0]  
intercept = model.intercept_  
y_pred = model.predict(x)
r2 = r2_score(y, y_pred)

x_with_intercept = sm.add_constant(x)
model_stats = sm.OLS(y, x_with_intercept).fit()
print(model_stats.summary())
print(f"Slope (Coefficient for 'time'): {slope}")
print(f"Intercept: {intercept}")
print(f"R-squared: {r2}")
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:             Arr_CUHI_5   R-squared:                       0.963
# Model:                            OLS   Adj. R-squared:                  0.963
# Method:                 Least Squares   F-statistic:                     2161.
# Date:                Fri, 15 Mar 2024   Prob (F-statistic):           3.31e-61
# Time:                        14:38:52   Log-Likelihood:                 245.33
# No. Observations:                  85   AIC:                            -486.7
# Df Residuals:                      83   BIC:                            -481.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.9022      0.006    152.861      0.000       0.890       0.914
# ...

# %%
df = pd.DataFrame(Arr_SUHI_5)
x = wl[['alb']]
y = df['Arr_SUHI_5']
model = LinearRegression()
model.fit(x, y)
slope = model.coef_[0]  
intercept = model.intercept_  
y_pred = model.predict(x)
r2 = r2_score(y, y_pred)

x_with_intercept = sm.add_constant(x)
model_stats = sm.OLS(y, x_with_intercept).fit()
print(model_stats.summary())
print(f"Slope (Coefficient for 'time'): {slope}")
print(f"Intercept: {intercept}")
print(f"R-squared: {r2}")
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:             Arr_SUHI_5   R-squared:                       0.979
# Model:                            OLS   Adj. R-squared:                  0.978
# Method:                 Least Squares   F-statistic:                     3801.
# Date:                Fri, 15 Mar 2024   Prob (F-statistic):           4.30e-71
# Time:                        14:39:14   Log-Likelihood:                 193.98
# No. Observations:                  85   AIC:                            -384.0
# Df Residuals:                      83   BIC:                            -379.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.5732      0.011    145.688      0.000       1.552       1.595
# ...

# %% [markdown]
# # combined effect

# %%
path = '/work/n02/n02/yuansun/cesm/'
# surface
sfile = path + 'cesm_inputdata/lnd/clm2/surfdata_map/release-clm5.0.18/surfdata_0.9x1.25_hist_16pfts_Irrig_CMIP6_simyr1850_c190214.nc'
ds_0 = xr.open_dataset(sfile)
mask = np.any(ds_0['PCT_URBAN'] != 0, axis=0)
mask = mask.rename({'lsmlat': 'lat', 'lsmlon': 'lon'})
#case4
path_4 = path + 'archive/case4/lnd/hist/'
#case6
path_6 = path + 'archive/case6/lnd/hist/'
ds4 = xr.open_dataset(path_4 + 'case4.clm2.h1.2099-02-01-00000.nc')
ds6 = xr.open_dataset(path_6 + 'case6.clm2.h1.2099-02-01-00000.nc')

# %%
suhi4_2099 = (ds4['TG_U']-ds4['TG_R']).where(mask).mean().values
print(suhi4_2099-Arr_SUHI_0[84])
# Out:
# -2.9254432916641235

# %%
suhi6_2099 = (ds6['TG_U']-ds6['TG_R']).where(mask).mean().values
print(suhi6_2099-Arr_SUHI_0[84])
# Out:
# -3.6983765363693237

# %%
print(Arr_SUHI_2[84]-Arr_SUHI_0[84])
# Out:
# -2.712373733520508

# %%
print(Arr_SUHI_3[84]-Arr_SUHI_0[84])
# Out:
# -0.18632578849792458

# %%
print(Arr_SUHI_5[84]-Arr_SUHI_0[84])
# Out:
# -0.4644670486450193
